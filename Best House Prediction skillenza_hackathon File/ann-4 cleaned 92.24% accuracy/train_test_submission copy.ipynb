# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

from sklearn.datasets import make_circles
import tensorflow as tf

import os
import random

from tensorflow.keras.layers import InputLayer, Dense

# %% [markdown]
# # Description of the data attributes is as below:
#
# - Area(total): Total area of the plot.
# - Trooms: Total Number of rooms in the house
# - Nbedrooms: Number of bedroom in the house
# - Nbwashrooms: Number of washroom attached with bedroom
# - Twashrooms: total number of washroom in the house.
# - Roof: Does the house has roof(yes or no)
# - Roof(Area): Total area of the terrace
# - Lawn(Area): Area of the lawn including garden and parking
# - Nfloor: Number of floors in the house
# - API: Air purity index api is in percentage for example if api is 85 it means its 85% of the standard api for the city.
# - ANB: Amenities near by amenities like hospital, park , multiplex , malls etc within 2 miles.
# - Expected price: price expected by seller.
# - Grade: Grade provided by company that depends on the condition and other features mentioned in the data. *(Note A is best garde and E is worst.)*
#
#  Evaluation: The metric of evaluation for this prediction problem is Accuracy.

# %%
old_training_df = pd.read_csv("TRAINING_.csv")
old_training_df.sample(5)
# Out:
#         id  Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms roof  \
# 364    365          359    9.0        2.0          1.0         3.0  yes
# 4079  4080          291    6.0        3.0          2.0         4.0   NO
# 5599  5600          337    5.0        2.0          2.0         3.0  NaN
# 1282  1283          297    9.0        5.0          3.0         5.0   no
# 489    490          305    5.0        5.0          3.0         5.0   NO
#
#       Roof(Area)  Lawn(Area)  Nfloors   API  ANB Grade EXPECTED
# 364        109.0        98.0        3  78.0    1     C    4630$
# 4079         0.0       100.0        1  89.0    3     D    3560$
# 5599         NaN        98.0        2  64.0    6     D    3756$
# 1282         0.0        89.0        5  84.0    2     C    4327$
# 489          0.0       108.0        4  86.0    6     D    3131$

# %%
old_training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           7000 non-null   int64
#  1   Area(total)  7000 non-null   int64
#  2   Troom        6998 non-null   float64
#  3   Nbedrooms    6997 non-null   float64
#  4   Nbwashrooms  6998 non-null   float64
#  5   Twashrooms   6999 non-null   float64
#  6   roof         5647 non-null   object
#  7   Roof(Area)   5647 non-null   float64
#  8   Lawn(Area)   6998 non-null   float64
#  9   Nfloors      7000 non-null   int64
#  10  API          6999 non-null   float64
#  11  ANB          7000 non-null   int64
#  12  Grade        7000 non-null   object
#  13  EXPECTED     7000 non-null   object
# dtypes: float64(7), int64(4), object(3)
# memory usage: 765.8+ KB

# %% [markdown]
# * removing "$" sign from "EXPECTED" column

# %%
old_training_df["EXPECTED"] = old_training_df["EXPECTED"].str.replace("$","").astype("float")

# %%
training_df = old_training_df.drop(columns=(["roof", "Roof(Area)", "Grade", "id"]))

# %% [markdown]
# ## Handling Missing Data

# %%
training_df.isnull().sum()
# Out:
# Area(total)    0
# Troom          2
# Nbedrooms      3
# Nbwashrooms    2
# Twashrooms     1
# Lawn(Area)     2
# Nfloors        0
# API            1
# ANB            0
# EXPECTED       0
# dtype: int64

# %% [markdown]
# * fill missing values using mean,mode

# %%
#mode
mode_col = ["Troom","Nbedrooms","Nbwashrooms","Twashrooms"]

#mean
mean_col= ["Lawn(Area)", "API"]

# %%
from sklearn.impute import SimpleImputer


si = SimpleImputer(strategy = "most_frequent")

training_df[mode_col] = pd.DataFrame(si.fit_transform(training_df[mode_col]), index = training_df.index, columns = mode_col)


si = SimpleImputer(strategy = "mean")
training_df[mean_col] = pd.DataFrame(si.fit_transform(training_df[mean_col]), index = training_df.index, columns = mean_col)

# %%
training_df.isnull().sum()
# Out:
# Area(total)    0
# Troom          0
# Nbedrooms      0
# Nbwashrooms    0
# Twashrooms     0
# Lawn(Area)     0
# Nfloors        0
# API            0
# ANB            0
# EXPECTED       0
# dtype: int64

# %%
training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area(total)  7000 non-null   int64
#  1   Troom        7000 non-null   float64
#  2   Nbedrooms    7000 non-null   float64
#  3   Nbwashrooms  7000 non-null   float64
#  4   Twashrooms   7000 non-null   float64
#  5   Lawn(Area)   7000 non-null   float64
#  6   Nfloors      7000 non-null   int64
#  7   API          7000 non-null   float64
#  8   ANB          7000 non-null   int64
#  9   EXPECTED     7000 non-null   float64
# dtypes: float64(7), int64(3)
# memory usage: 547.0 KB

# %% [markdown]
# * ------- all missing values are handled in training_df ( 9 - columns )----------------

# %% [markdown]
# ## scaling

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

df_training_scale = pd.DataFrame(ss.fit_transform(training_df), columns=training_df.columns, index=training_df.index)

# %%
df_training_scale
# Out:
#       Area(total)     Troom  Nbedrooms  Nbwashrooms  Twashrooms  Lawn(Area)  \
# 0       -0.984255  0.695196  -1.810562    -1.881612   -1.657462   -1.181860
# 1        0.913637 -0.713102   1.214099     1.876064    1.655947   -0.589151
# 2       -1.519558  0.695196  -0.600698    -0.629053   -0.994780   -1.012515
# 3        0.135015 -1.417250  -0.600698    -1.255332   -0.994780    0.088230
# 4       -1.470894  1.399345   0.004235    -0.629053   -0.332098    0.596266
# ...           ...       ...        ...          ...         ...         ...
# 6995    -0.935591  0.695196  -1.810562    -1.881612   -1.657462   -1.012515
# 6996     0.767645 -1.417250  -1.205630    -1.255332   -0.994780   -1.520551
# 6997    -0.935591 -0.713102  -0.600698    -1.255332   -0.994780   -0.843169
# 6998     0.621653  0.695196   1.214099     1.249785    0.993265    0.426921
# 6999    -0.546280 -1.417250   0.609167    -0.002774    0.330584   -0.843169
#
#        Nfloors       API       ANB  EXPECTED
# 0    -1.370481 -1.348076  0.297170 -0.423898
# 1     1.360183  1.520941 -1.467196  0.849083
# 2    -1.916614  0.761495  0.297170  0.327403
# 3     0.267917  0.592730 -1.467196 -1.157071
# 4    -0.278216  1.183409 -0.290952  1.020291
# ...        ...       ...       ...       ...
# 6995 -1.916614 -0.504247  0.885291 -0.643447
# 6996 -0.278216 -0.251099  0.297170 -1.404819
# 6997 -0.278216  1.436558  0.297170 -0.417856
# 6998 -0.278216  0.423964 -1.467196  0.909510
# 6999 -0.278216  1.436558 -0.879074 -1.245696
#
# [7000 rows x 10 columns]

# %% [markdown]
# ## k-mean

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=42, n_init='auto')

kmeans.fit(df_training_scale)
# Out:
# KMeans(n_clusters=5, n_init='auto', random_state=42)

# %%
training_df["cluster"] = kmeans.labels_

# %%
training_df["Roof(Area)"] = old_training_df["Roof(Area)"]

# %%
training_df.groupby(["cluster"])["Roof(Area)"].mean()
# Out:
# cluster
# 0    44.518554
# 1    46.198919
# 2    44.628081
# 3    49.198255
# 4    51.573296
# Name: Roof(Area), dtype: float64

# %%
zero = training_df["cluster"]==0
training_df.loc[zero] = training_df.loc[zero].fillna(value= 44.518554)


one = training_df["cluster"]==1
training_df.loc[one] = training_df.loc[one].fillna(value= 46.198919)


two = training_df["cluster"]==2
training_df.loc[two] = training_df.loc[two].fillna(value= 44.628081)


three = training_df["cluster"]==3
training_df.loc[three] = training_df.loc[three].fillna(value= 49.198255)


four = training_df["cluster"]==4
training_df.loc[four] = training_df.loc[four].fillna(value= 51.573296)

# %%
training_df.isnull().sum()
# Out:
# Area(total)    0
# Troom          0
# Nbedrooms      0
# Nbwashrooms    0
# Twashrooms     0
# Lawn(Area)     0
# Nfloors        0
# API            0
# ANB            0
# EXPECTED       0
# cluster        0
# Roof(Area)     0
# dtype: int64

# %% [markdown]
# * ---------------------- all missing values are handled in training_df ( 12 - columns, drop= [ "id" , "roof" ] ) --------------------------------

# %% [markdown]
# ## training_df

# %%
training_df.drop(columns=["cluster"], inplace=True)

# %%
training_df = pd.concat([training_df,old_training_df["Grade"]],axis=1)

# %%
training_df["Grade"] = training_df["Grade"].replace({"A":4, "B":3, "C":2, "D":1, "E":0})

# %%
training_df
# Out:
#       Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms  Lawn(Area)  \
# 0             305    8.0        2.0          1.0         3.0        76.0
# 1             344    6.0        7.0          7.0         8.0        83.0
# 2             294    8.0        4.0          3.0         4.0        78.0
# 3             328    5.0        4.0          2.0         4.0        91.0
# 4             295    9.0        5.0          3.0         5.0        97.0
# ...           ...    ...        ...          ...         ...         ...
# 6995          306    8.0        2.0          1.0         3.0        78.0
# 6996          341    5.0        3.0          2.0         4.0        72.0
# 6997          306    6.0        4.0          2.0         4.0        80.0
# 6998          338    8.0        7.0          6.0         7.0        95.0
# 6999          314    5.0        6.0          4.0         6.0        80.0
#
#       Nfloors   API  ANB  EXPECTED  Roof(Area)  Grade
# 0           2  63.0    4    3826.0    0.000000      1
# 1           7  97.0    1    4458.0    0.000000      3
# 2           1  88.0    4    4199.0   97.000000      2
# 3           5  86.0    1    3462.0    0.000000      1
# 4           4  93.0    3    4543.0   49.198255      2
# ...       ...   ...  ...       ...         ...    ...
# 6995        1  73.0    5    3717.0   44.628081      1
# 6996        4  76.0    4    3339.0  100.000000      1
# 6997        4  96.0    4    3829.0   83.000000      1
# 6998        4  84.0    1    4488.0    0.000000      3
# 6999        4  96.0    2    3418.0  109.000000      2
#
# [7000 rows x 12 columns]

# %% [markdown]
# ## x,y

# %%
X = training_df.drop(columns=["Grade"])
y = training_df["Grade"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

print(X_train.shape)
print(X_test.shape)
# Out:
# (5250, 11)
# (1750, 11)

# %% [markdown]
# ## scale

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_train_scale = pd.DataFrame(ss.fit_transform(X_train), index=X_train.index, columns=X_train.columns)
X_test_scale = pd.DataFrame(ss.transform(X_test), index=X_test.index, columns=X_test.columns)

# %% [markdown]
# ## <center>~ Applying Models ~

# %% [markdown]
# ## Applying ANN model
# * ann is gives good accuracy compaired to other model like - [ LogisticRegression, DecisionTreeClassifier, RandomForestClassifier,  GradientBoostingClassifier, XGBClassifier]

# %%
def set_seed(seed: int = 42) -> None:
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  tf.experimental.numpy.random.seed(seed)
  tf.random.set_seed(seed)
  os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
  os.environ['TF_DETERMINISTIC_OPS'] = '1'
  # Set a fixed value for the hash seed
  os.environ["PYTHONHASHSEED"] = str(seed)
  print(f"Random seed set as {seed}")

# %%
def plot_curve(history):
    history_df = pd.DataFrame(history.history)

    fig, ax = plt.subplots(1,2, figsize = (10,4))

    sns.lineplot(data = history_df,x = history_df.index+1, y = "loss", label = "training_loss", ax = ax[0])
    sns.lineplot(data = history_df,x = history_df.index+1, y = "val_loss", label = "validation_loss",ax = ax[0])


    sns.lineplot(data = history_df,x = history_df.index+1, y = "accuracy", label = "training_accuracy", ax = ax[1])
    sns.lineplot(data = history_df,x = history_df.index+1, y = "val_accuracy", label = "validation_accuracy", ax = ax[1])

    fig.suptitle("loss & accuracy curve plot")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## ann - 4 *

# %%
import tensorflow as tf
from tensorflow.keras.layers import InputLayer, Dense,Dropout

set_seed(42)

# model creation
ann4 = tf.keras.Sequential([
    InputLayer(input_shape=(11,)),

    Dense(150, 'relu'),
    Dropout(0.2),

    Dense(100, 'relu'),
    Dense(50, 'relu'),
    Dropout(0.2),

    Dense(5, 'softmax')])

# model compile
ann4.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# model fit
result4 = ann4.fit(X_train_scale, y_train, epochs=40, batch_size=12, validation_data=(X_test_scale, y_test))
# Out:
# Random seed set as 42
# Epoch 1/40
# 145/438 [========>.....................] - ETA: 0s - loss: 1.3094 - accuracy: 0.5345
# 438/438 [==============================] - 4s 5ms/step - loss: 0.9613 - accuracy: 0.6707 - val_loss: 0.5592 - val_accuracy: 0.8034
# Epoch 2/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.5313 - accuracy: 0.7981 - val_loss: 0.4092 - val_accuracy: 0.8514
# Epoch 3/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.4395 - accuracy: 0.8265 - val_loss: 0.3467 - val_accuracy: 0.8686
# Epoch 4/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3864 - accuracy: 0.8514 - val_loss: 0.3090 - val_accuracy: 0.8846
# Epoch 5/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3483 - accuracy: 0.8682 - val_loss: 0.3007 - val_accuracy: 0.8886
# Epoch 6/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3100 - accuracy: 0.8808 - val_loss: 0.2600 - val_accuracy: 0.8994
# Epoch 7/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2947 - accuracy: 0.8853 - val_loss: 0.2507 - val_accuracy: 0.9046
# Epoch 8/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2658 - accuracy: 0.8987 - val_loss: 0.2381 - val_accuracy: 0.8943
# Epoch 9/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2713 - accuracy: 0.8928 - val_loss: 0.2343 - val_accuracy: 0.9029
# Epoch 10/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2599 - accuracy: 0.9004 - val_loss: 0.2397 - val_accuracy: 0.9046
# Epoch 11/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2511 - accuracy: 0.9082 - val_loss: 0.2144 - val_accuracy: 0.9137
# Epoch 12/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2379 - accuracy: 0.9034 - val_loss: 0.2105 - val_accuracy: 0.9120
# Epoch 13/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2338 - accuracy: 0.9057 - val_loss: 0.2055 - val_accuracy: 0.9103
# Epoch 14/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2293 - accuracy: 0.9055 - val_loss: 0.2095 - val_accuracy: 0.9069
# Epoch 15/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2133 - accuracy: 0.9156 - val_loss: 0.2168 - val_accuracy: 0.9080
# Epoch 16/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2184 - accuracy: 0.9166 - val_loss: 0.1899 - val_accuracy: 0.9217
# Epoch 17/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2075 - accuracy: 0.9141 - val_loss: 0.1994 - val_accuracy: 0.9154
# Epoch 18/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2119 - accuracy: 0.9175 - val_loss: 0.1848 - val_accuracy: 0.9229
# Epoch 19/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2077 - accuracy: 0.9179 - val_loss: 0.1918 - val_accuracy: 0.9166
# Epoch 20/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1983 - accuracy: 0.9194 - val_loss: 0.1923 - val_accuracy: 0.9183
# Epoch 21/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1981 - accuracy: 0.9208 - val_loss: 0.1834 - val_accuracy: 0.9263
# Epoch 22/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1965 - accuracy: 0.9211 - val_loss: 0.2133 - val_accuracy: 0.9086
# Epoch 23/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1845 - accuracy: 0.9263 - val_loss: 0.1882 - val_accuracy: 0.9234
# Epoch 24/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1875 - accuracy: 0.9232 - val_loss: 0.2011 - val_accuracy: 0.9097
# Epoch 25/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1779 - accuracy: 0.9263 - val_loss: 0.1743 - val_accuracy: 0.9263
# Epoch 26/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1816 - accuracy: 0.9269 - val_loss: 0.1663 - val_accuracy: 0.9291
# Epoch 27/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1811 - accuracy: 0.9276 - val_loss: 0.1700 - val_accuracy: 0.9263
# Epoch 28/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1693 - accuracy: 0.9301 - val_loss: 0.1620 - val_accuracy: 0.9337
# Epoch 29/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1728 - accuracy: 0.9291 - val_loss: 0.1733 - val_accuracy: 0.9280
# Epoch 30/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1718 - accuracy: 0.9259 - val_loss: 0.1745 - val_accuracy: 0.9240
# Epoch 31/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1728 - accuracy: 0.9291 - val_loss: 0.1698 - val_accuracy: 0.9251
# Epoch 32/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1742 - accuracy: 0.9299 - val_loss: 0.1709 - val_accuracy: 0.9229
# Epoch 33/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1693 - accuracy: 0.9310 - val_loss: 0.1579 - val_accuracy: 0.9314
# Epoch 34/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1676 - accuracy: 0.9288 - val_loss: 0.1767 - val_accuracy: 0.9223
# Epoch 35/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1663 - accuracy: 0.9328 - val_loss: 0.1610 - val_accuracy: 0.9269
# Epoch 36/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1599 - accuracy: 0.9339 - val_loss: 0.1629 - val_accuracy: 0.9326
# Epoch 37/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1590 - accuracy: 0.9354 - val_loss: 0.1500 - val_accuracy: 0.9331
# Epoch 38/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1588 - accuracy: 0.9322 - val_loss: 0.1510 - val_accuracy: 0.9343
# Epoch 39/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1538 - accuracy: 0.9383 - val_loss: 0.1651 - val_accuracy: 0.9291
# Epoch 40/40
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1651 - accuracy: 0.9330 - val_loss: 0.1704 - val_accuracy: 0.9251

# %%
plot_curve(result4)

# %% [markdown]
# * model

# %%
ann4.evaluate(X_test_scale, y_test)
# Out:
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1704 - accuracy: 0.9251
# [0.17041394114494324, 0.9251428842544556]

# %%
y_pred_ann_4 = ann4.predict(X_test_scale)
# Out:
# 55/55 [==============================] - 0s 2ms/step

# %%
y_pred_4 = np.argmax(y_pred_ann_4, axis= 1)

# %%
print(classification_report(y_test, y_pred_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.95      0.94      0.94       514
#            2       0.93      0.95      0.94       747
#            3       0.94      0.86      0.90       371
#            4       0.79      0.99      0.88       112
#
#     accuracy                           0.93      1750
#    macro avg       0.72      0.75      0.73      1750
# weighted avg       0.92      0.93      0.92      1750
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
ann4.save("ann_model_4")
# Out:
# INFO:tensorflow:Assets written to: ann_model_4\assets
# INFO:tensorflow:Assets written to: ann_model_4\assets

# %%
load_model_4 = tf.keras.models.load_model("ann_model_4")

# %%
pd.Series(np.argmax(load_model_4.predict(X_test_scale),axis=1)).value_counts()
# Out:
# 55/55 [==============================] - 0s 2ms/step
# 2    762
# 1    507
# 3    341
# 4    140
# Name: count, dtype: int64

# %%
# ann5.evaluate(X_test_scale, y_test)
# y_pred_ann5 = ann5.predict(X_test_scale)
# y_pred_5 = np.argmax(y_pred_ann5, axis= 1)
# print(classification_report(y_test, y_pred_5))

# # -----------------------------------------
# ann6.save("ann_model6")
# load_model_6 = tf.keras.models.load_model("ann_model6")
# pd.Series(np.argmax(load_model_6.predict(X_test_scale),axis=1)).value_counts()

# %% [markdown]
# ## ann - 5

# %%
import tensorflow as tf
from tensorflow.keras.layers import InputLayer, Dense,Dropout

set_seed(42)

# model creation
ann5 = tf.keras.Sequential([
    InputLayer(input_shape=(11,)),

    Dense(100, 'relu'),
    Dropout(0.2),

    Dense(70, 'relu'),
    Dense(50, 'relu'),
    Dense(20, 'relu'),

    Dropout(0.2),

    Dense(5, 'softmax')])

# model compile
ann5.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# model fit
result5 = ann5.fit(X_train_scale, y_train, epochs=50,batch_size=12, validation_data=(X_test_scale, y_test))
# Out:
# Random seed set as 42
# Epoch 1/50
# 438/438 [==============================] - 3s 5ms/step - loss: 1.1084 - accuracy: 0.5507 - val_loss: 0.6313 - val_accuracy: 0.7949
# Epoch 2/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.6034 - accuracy: 0.7789 - val_loss: 0.4507 - val_accuracy: 0.8371
# Epoch 3/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.4858 - accuracy: 0.8211 - val_loss: 0.3591 - val_accuracy: 0.8749
# Epoch 4/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.4253 - accuracy: 0.8425 - val_loss: 0.3208 - val_accuracy: 0.8857
# Epoch 5/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3743 - accuracy: 0.8577 - val_loss: 0.3119 - val_accuracy: 0.8846
# Epoch 6/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3525 - accuracy: 0.8699 - val_loss: 0.2848 - val_accuracy: 0.9011
# Epoch 7/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3383 - accuracy: 0.8728 - val_loss: 0.2743 - val_accuracy: 0.8909
# Epoch 8/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3188 - accuracy: 0.8821 - val_loss: 0.2525 - val_accuracy: 0.9017
# Epoch 9/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3116 - accuracy: 0.8838 - val_loss: 0.2466 - val_accuracy: 0.9034
# Epoch 10/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2960 - accuracy: 0.8870 - val_loss: 0.2603 - val_accuracy: 0.9006
# Epoch 11/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2814 - accuracy: 0.8962 - val_loss: 0.2356 - val_accuracy: 0.9080
# Epoch 12/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2719 - accuracy: 0.8943 - val_loss: 0.2299 - val_accuracy: 0.9114
# Epoch 13/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2696 - accuracy: 0.8971 - val_loss: 0.2198 - val_accuracy: 0.9126
# Epoch 14/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2577 - accuracy: 0.9048 - val_loss: 0.2257 - val_accuracy: 0.9069
# Epoch 15/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2570 - accuracy: 0.9063 - val_loss: 0.2109 - val_accuracy: 0.9177
# Epoch 16/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2444 - accuracy: 0.9105 - val_loss: 0.2017 - val_accuracy: 0.9194
# Epoch 17/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2468 - accuracy: 0.9080 - val_loss: 0.2030 - val_accuracy: 0.9126
# Epoch 18/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2398 - accuracy: 0.9055 - val_loss: 0.1965 - val_accuracy: 0.9166
# Epoch 19/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2364 - accuracy: 0.9120 - val_loss: 0.1921 - val_accuracy: 0.9171
# Epoch 20/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2299 - accuracy: 0.9131 - val_loss: 0.2064 - val_accuracy: 0.9137
# Epoch 21/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2313 - accuracy: 0.9131 - val_loss: 0.1932 - val_accuracy: 0.9223
# Epoch 22/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2149 - accuracy: 0.9183 - val_loss: 0.2487 - val_accuracy: 0.8926
# Epoch 23/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2145 - accuracy: 0.9185 - val_loss: 0.2048 - val_accuracy: 0.9149
# Epoch 24/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2066 - accuracy: 0.9192 - val_loss: 0.1854 - val_accuracy: 0.9217
# Epoch 25/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2050 - accuracy: 0.9221 - val_loss: 0.1761 - val_accuracy: 0.9246
# Epoch 26/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1932 - accuracy: 0.9255 - val_loss: 0.1726 - val_accuracy: 0.9274
# Epoch 27/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2137 - accuracy: 0.9131 - val_loss: 0.1747 - val_accuracy: 0.9314
# Epoch 28/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1950 - accuracy: 0.9257 - val_loss: 0.1845 - val_accuracy: 0.9211
# Epoch 29/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1974 - accuracy: 0.9253 - val_loss: 0.1841 - val_accuracy: 0.9257
# Epoch 30/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1993 - accuracy: 0.9189 - val_loss: 0.1717 - val_accuracy: 0.9251
# Epoch 31/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1847 - accuracy: 0.9265 - val_loss: 0.1777 - val_accuracy: 0.9223
# Epoch 32/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1918 - accuracy: 0.9208 - val_loss: 0.1647 - val_accuracy: 0.9263
# Epoch 33/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1833 - accuracy: 0.9261 - val_loss: 0.1786 - val_accuracy: 0.9211
# Epoch 34/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1886 - accuracy: 0.9280 - val_loss: 0.2135 - val_accuracy: 0.9074
# Epoch 35/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1861 - accuracy: 0.9248 - val_loss: 0.1658 - val_accuracy: 0.9303
# Epoch 36/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1871 - accuracy: 0.9250 - val_loss: 0.1655 - val_accuracy: 0.9314
# Epoch 37/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1864 - accuracy: 0.9261 - val_loss: 0.1587 - val_accuracy: 0.9297
# Epoch 38/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1690 - accuracy: 0.9307 - val_loss: 0.1645 - val_accuracy: 0.9280
# Epoch 39/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1815 - accuracy: 0.9255 - val_loss: 0.1833 - val_accuracy: 0.9200
# Epoch 40/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1833 - accuracy: 0.9286 - val_loss: 0.1650 - val_accuracy: 0.9280
# Epoch 41/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1636 - accuracy: 0.9360 - val_loss: 0.1724 - val_accuracy: 0.9217
# Epoch 42/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1814 - accuracy: 0.9282 - val_loss: 0.1829 - val_accuracy: 0.9120
# Epoch 43/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1745 - accuracy: 0.9301 - val_loss: 0.1964 - val_accuracy: 0.9131
# Epoch 44/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1680 - accuracy: 0.9352 - val_loss: 0.1714 - val_accuracy: 0.9240
# Epoch 45/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1667 - accuracy: 0.9347 - val_loss: 0.1809 - val_accuracy: 0.9206
# Epoch 46/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1692 - accuracy: 0.9310 - val_loss: 0.1669 - val_accuracy: 0.9257
# Epoch 47/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1644 - accuracy: 0.9333 - val_loss: 0.1981 - val_accuracy: 0.9137
# Epoch 48/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1690 - accuracy: 0.9370 - val_loss: 0.1680 - val_accuracy: 0.9223
# Epoch 49/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1604 - accuracy: 0.9333 - val_loss: 0.1724 - val_accuracy: 0.9166
# Epoch 50/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1592 - accuracy: 0.9335 - val_loss: 0.1792 - val_accuracy: 0.9217

# %%
plot_curve(result5)

# %%
ann5.evaluate(X_test_scale, y_test)
# Out:
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1792 - accuracy: 0.9217
# [0.17924000322818756, 0.9217143058776855]

# %%
y_pred_ann5 = ann5.predict(X_test_scale)
# Out:
# 55/55 [==============================] - 0s 2ms/step

# %%
y_pred_5 = np.argmax(y_pred_ann5, axis= 1)

# %%
print(classification_report(y_test, y_pred_5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.95      0.94      0.95       514
#            2       0.91      0.97      0.94       747
#            3       0.90      0.88      0.89       371
#            4       0.99      0.73      0.84       112
#
#     accuracy                           0.92      1750
#    macro avg       0.75      0.70      0.72      1750
# weighted avg       0.92      0.92      0.92      1750
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# * save model (ann5)

# %%
ann5.save("ann_model5")
# Out:
# INFO:tensorflow:Assets written to: ann_model5\assets
# INFO:tensorflow:Assets written to: ann_model5\assets

# %%
load_model_5 = tf.keras.models.load_model("ann_model5")

# %%
pd.Series(np.argmax(load_model_5.predict(X_test_scale),axis=1)).value_counts()
# Out:
# 55/55 [==============================] - 0s 2ms/step
# 2    795
# 1    509
# 3    363
# 4     83
# Name: count, dtype: int64

# %%
# !zip -r /content/ann_model5.zip /content/ann_model5
# Out:
# 'zip' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## ann -6 v.

# %%
import tensorflow as tf
from tensorflow.keras.layers import InputLayer, Dense,Dropout

set_seed(42)

# model creation
ann6 = tf.keras.Sequential([
    InputLayer(input_shape=(11,)),

    Dense(256, 'relu'),
    Dropout(0.2),

    Dense(128, 'relu'),
    Dense(64, 'relu'),
    Dense(32, 'relu'),

    Dropout(0.2),

    Dense(5, 'softmax')])

# model compile
ann6.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# model fit
result6 = ann6.fit(X_train_scale, y_train, epochs=50,batch_size=12, validation_data=(X_test_scale, y_test))
# Out:
# Random seed set as 42
# Epoch 1/50
# 438/438 [==============================] - 4s 5ms/step - loss: 1.0564 - accuracy: 0.6255 - val_loss: 0.6247 - val_accuracy: 0.8171
# Epoch 2/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.5494 - accuracy: 0.8105 - val_loss: 0.4002 - val_accuracy: 0.8686
# Epoch 3/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.4090 - accuracy: 0.8520 - val_loss: 0.3188 - val_accuracy: 0.8846
# Epoch 4/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3628 - accuracy: 0.8699 - val_loss: 0.2793 - val_accuracy: 0.8960
# Epoch 5/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.3149 - accuracy: 0.8823 - val_loss: 0.2754 - val_accuracy: 0.8977
# Epoch 6/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.2986 - accuracy: 0.8912 - val_loss: 0.2399 - val_accuracy: 0.9063
# Epoch 7/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2806 - accuracy: 0.8950 - val_loss: 0.2350 - val_accuracy: 0.9069
# Epoch 8/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2597 - accuracy: 0.9050 - val_loss: 0.2193 - val_accuracy: 0.9114
# Epoch 9/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2459 - accuracy: 0.9074 - val_loss: 0.2272 - val_accuracy: 0.9069
# Epoch 10/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2370 - accuracy: 0.9110 - val_loss: 0.2131 - val_accuracy: 0.9114
# Epoch 11/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2242 - accuracy: 0.9156 - val_loss: 0.2057 - val_accuracy: 0.9114
# Epoch 12/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2200 - accuracy: 0.9147 - val_loss: 0.1937 - val_accuracy: 0.9206
# Epoch 13/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2142 - accuracy: 0.9194 - val_loss: 0.1884 - val_accuracy: 0.9234
# Epoch 14/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.2049 - accuracy: 0.9208 - val_loss: 0.2144 - val_accuracy: 0.9046
# Epoch 15/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1992 - accuracy: 0.9225 - val_loss: 0.2034 - val_accuracy: 0.9126
# Epoch 16/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1995 - accuracy: 0.9198 - val_loss: 0.1844 - val_accuracy: 0.9240
# Epoch 17/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1905 - accuracy: 0.9272 - val_loss: 0.1891 - val_accuracy: 0.9211
# Epoch 18/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1808 - accuracy: 0.9318 - val_loss: 0.1766 - val_accuracy: 0.9240
# Epoch 19/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1867 - accuracy: 0.9269 - val_loss: 0.1826 - val_accuracy: 0.9263
# Epoch 20/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1739 - accuracy: 0.9335 - val_loss: 0.1767 - val_accuracy: 0.9223
# Epoch 21/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1786 - accuracy: 0.9316 - val_loss: 0.1945 - val_accuracy: 0.9246
# Epoch 22/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1736 - accuracy: 0.9303 - val_loss: 0.1839 - val_accuracy: 0.9200
# Epoch 23/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1680 - accuracy: 0.9305 - val_loss: 0.1838 - val_accuracy: 0.9217
# Epoch 24/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1714 - accuracy: 0.9295 - val_loss: 0.2012 - val_accuracy: 0.9109
# Epoch 25/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1656 - accuracy: 0.9335 - val_loss: 0.1860 - val_accuracy: 0.9166
# Epoch 26/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1566 - accuracy: 0.9408 - val_loss: 0.1584 - val_accuracy: 0.9291
# Epoch 27/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1601 - accuracy: 0.9358 - val_loss: 0.1678 - val_accuracy: 0.9286
# Epoch 28/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1671 - accuracy: 0.9312 - val_loss: 0.1677 - val_accuracy: 0.9229
# Epoch 29/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1558 - accuracy: 0.9358 - val_loss: 0.1466 - val_accuracy: 0.9389
# Epoch 30/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1652 - accuracy: 0.9301 - val_loss: 0.1785 - val_accuracy: 0.9109
# Epoch 31/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1551 - accuracy: 0.9387 - val_loss: 0.1784 - val_accuracy: 0.9217
# Epoch 32/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1542 - accuracy: 0.9385 - val_loss: 0.1579 - val_accuracy: 0.9303
# Epoch 33/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1450 - accuracy: 0.9375 - val_loss: 0.1583 - val_accuracy: 0.9320
# Epoch 34/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1343 - accuracy: 0.9478 - val_loss: 0.1937 - val_accuracy: 0.9126
# Epoch 35/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1493 - accuracy: 0.9406 - val_loss: 0.1519 - val_accuracy: 0.9303
# Epoch 36/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1484 - accuracy: 0.9434 - val_loss: 0.1497 - val_accuracy: 0.9389
# Epoch 37/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1380 - accuracy: 0.9450 - val_loss: 0.1546 - val_accuracy: 0.9343
# Epoch 38/50
# 418/438 [===========================>..] - ETA: 0s - loss: 0.1389 - accuracy: 0.9424
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Manish Gupta\Desktop\skillenza\sub-6\train_test_submission.ipynb Cell 60 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/sub-6/train_test_submission.ipynb#Y163sZmlsZQ%3D%3D?line=21'>22</a> ann6.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
#      <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/sub-6/train_test_submission.ipynb#Y163sZmlsZQ%3D%3D?line=23'>24</a> # model fit
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/sub-6/train_test_submission.ipynb#Y163sZmlsZQ%3D%3D?line=24'>25</a> result6 = ann6.fit(X_train_scale, y_train, epochs=50,batch_size=12, validation_data=(X_test_scale, y_test))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
plot_curve(result6)

# %%
.py

# %%
ann6.save("ann_model6")

# %%
load_model_6 = tf.keras.models.load_model("ann_model6")

# %%
pd.Series(np.argmax(load_model_6.predict(X_test_scale),axis=1)).value_counts()
# Out:
# 44/44 [==============================] - 0s 2ms/step
# 2    601
# 1    417
# 3    302
# 4     79
# 0      1
# dtype: int64

# %%
# !zip -r /content/ann_model_6.zip /content/ann_model6
# Out:
#   adding: content/ann_model6/ (stored 0%)
#   adding: content/ann_model6/keras_metadata.pb (deflated 90%)
#   adding: content/ann_model6/fingerprint.pb (stored 0%)
#   adding: content/ann_model6/variables/ (stored 0%)
#   adding: content/ann_model6/variables/variables.index (deflated 59%)
#   adding: content/ann_model6/variables/variables.data-00000-of-00001 (deflated 16%)
#   adding: content/ann_model6/assets/ (stored 0%)
#   adding: content/ann_model6/saved_model.pb (deflated 88%)

# %% [markdown]
# # <center> Working on test data

# %%
test_df = pd.read_csv('TEST_.csv')
test_df.sample(5)
# Out:
#         id  Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms roof  \
# 2129  2130          326    8.0        5.0          6.0           7  YES
# 1278  1279          331    6.0        6.0          4.0           6  YES
# 3153  3154          328    5.0        8.0          6.0           8   no
# 2417  2418          296    9.0        7.0          5.0           7   no
# 2179  2180          348    7.0        7.0          4.0           6   no
#
#       Roof(Area)  Lawn(Area)  Nfloors   API  ANB EXPECTED
# 2129        91.0       103.0        7  93.0    5    4812$
# 1278       110.0        90.0        4  65.0    4    3709$
# 3153         0.0       105.0        5  84.0    2    4346$
# 2417         0.0       105.0        7  97.0    6    4709$
# 2179         0.0        97.0        5  77.0    3    4250$

# %%
test_df.shape
# Out:
# (3299, 13)

# %%
test_df.isnull().sum()[test_df.isnull().sum()>0]
# Out:
# Troom            1
# Nbedrooms        1
# Nbwashrooms      1
# roof           653
# Roof(Area)     653
# Lawn(Area)       1
# API              1
# dtype: int64

# %%
test_df['EXPECTED'] = test_df['EXPECTED'].str.strip('$').astype(float)

# %%
test_df.drop(columns=['id'], inplace=True)

# %%
new_test_df = test_df.drop(columns = ['roof', 'Roof(Area)'])
new_test_df.head(7)
# Out:
#    Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms  Lawn(Area)  \
# 0          348    9.0        5.0          3.0           5        84.0
# 1          311    6.0        5.0          5.0           6        86.0
# 2          342    5.0        6.0          6.0           7        85.0
# 3          329    7.0        7.0          4.0           6       105.0
# 4          307    6.0        2.0          3.0           4        76.0
# 5          297    6.0        6.0          4.0           6       103.0
# 6          292    9.0        7.0          6.0           7       101.0
#
#    Nfloors   API  ANB  EXPECTED
# 0        5  91.0    6    4422.0
# 1        6  83.0    4    3432.0
# 2        4  95.0    5    4066.0
# 3        5  97.0    6    4322.0
# 4        2  64.0    4    3031.0
# 5        6  73.0    6    4223.0
# 6        5  88.0    5    4993.0

# %%
new_test_df.isnull().sum()[new_test_df.isnull().sum() > 0]
# Out:
# Troom          1
# Nbedrooms      1
# Nbwashrooms    1
# Lawn(Area)     1
# API            1
# dtype: int64

# %%
mode_cols = ['Troom', 'Nbedrooms', 'Nbwashrooms']
mean_cols = ['Lawn(Area)', 'API']

new_test_df[mode_cols] = new_test_df[mode_cols].fillna(test_df[mode_cols].mode().iloc[0])
new_test_df[mean_cols] = new_test_df[mean_cols].fillna(test_df[mean_cols].mean())

# %%
scaler = StandardScaler()
new_test_df_scale = pd.DataFrame(scaler.fit_transform(new_test_df), index = new_test_df.index, columns=new_test_df.columns)
new_test_df_scale.head(2)
# Out:
#    Area(total)     Troom  Nbedrooms  Nbwashrooms  Twashrooms  Lawn(Area)  \
# 0     1.154616  1.421814  -0.000933    -0.650541   -0.341896   -0.517482
# 1    -0.665650 -0.691688  -0.000933     0.642311    0.339623   -0.348648
#
#     Nfloors       API       ANB  EXPECTED
# 0  0.276844  1.004131  1.477486  0.815526
# 1  0.838533  0.326682  0.298570 -1.222186

# %%
km = KMeans(n_clusters= 5, random_state=42, n_init = 10)
km.fit(new_test_df_scale)
# Out:
# KMeans(n_clusters=5, n_init=10, random_state=42)

# %%
new_test_df['K_cluster'] = km.labels_

# %%
new_test_df['Roof(Area)'] = test_df['Roof(Area)']

# %%
new_test_df.groupby(by='K_cluster')['Roof(Area)'].mean()
# Out:
# K_cluster
# 0    49.977186
# 1    46.112903
# 2    46.326718
# 3    46.603912
# 4    47.479920
# Name: Roof(Area), dtype: float64

# %%
cluster_median_mapping = {
    0: 49.977186,
    1: 46.112903,
    2: 46.326718,
    3: 46.603912,
    4: 47.479920
}

# Fill missing values with the cluster mean
new_test_df['Roof(Area)'].fillna(new_test_df['K_cluster'].map(cluster_median_mapping), inplace=True)

# %%
new_test_df.drop(columns=['K_cluster'], inplace=True)

# %%
## Standardizing
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
test_std = pd.DataFrame(scale.fit_transform(new_test_df), index=new_test_df.index, columns=new_test_df.columns)

# %%
test_std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3299 entries, 0 to 3298
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area(total)  3299 non-null   float64
#  1   Troom        3299 non-null   float64
#  2   Nbedrooms    3299 non-null   float64
#  3   Nbwashrooms  3299 non-null   float64
#  4   Twashrooms   3299 non-null   float64
#  5   Lawn(Area)   3299 non-null   float64
#  6   Nfloors      3299 non-null   float64
#  7   API          3299 non-null   float64
#  8   ANB          3299 non-null   float64
#  9   EXPECTED     3299 non-null   float64
#  10  Roof(Area)   3299 non-null   float64
# dtypes: float64(11)
# memory usage: 283.6 KB

# %% [markdown]
# ## load model

# %%
load_model = tf.keras.models.load_model('ann_model_4')

# %%
pd.Series(np.argmax(load_model.predict(test_std), axis=1)).value_counts()
# Out:
# 104/104 [==============================] - 0s 3ms/step
# 2    1432
# 1     983
# 3     625
# 4     257
# 0       2
# Name: count, dtype: int64

# %%
final_df = pd.DataFrame()

# %% [markdown]
# # read test_.csv

# %%
test_df = pd.read_csv('TEST_.csv')

# %%
final_df['id'] = test_df['id']

# %%
final_df["Grade"] = np.argmax(load_model.predict(test_std), axis=1)
# Out:
# 104/104 [==============================] - 0s 2ms/step

# %%
final_df["Grade"].replace({4:"A", 3:"B", 2:"C", 1:"D", 0:"E"}, inplace=True)

# %%
final_df.to_csv('submission_4.csv', index=False)

# %% [markdown]
# ## save model

# %%
# ann5.evaluate(X_test_scale, y_test)
# y_pred_ann5 = ann5.predict(X_test_scale)
# y_pred_5 = np.argmax(y_pred_ann5, axis= 1)
# print(classification_report(y_test, y_pred_5))

# # -----------------------------------------
# ann6.save("ann_model6")
# load_model_6 = tf.keras.models.load_model("ann_model6")
# pd.Series(np.argmax(load_model_6.predict(X_test_scale),axis=1)).value_counts()
# # ------------------------------------------

# !zip -r /content/ann_model_6.zip /content/ann_model6
