# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

from sklearn.datasets import make_circles
import tensorflow as tf

import os
import random

from tensorflow.keras.layers import InputLayer, Dense

# %% [markdown]
# # Description of the data attributes is as below:
#
# - Area(total): Total area of the plot.
# - Trooms: Total Number of rooms in the house
# - Nbedrooms: Number of bedroom in the house
# - Nbwashrooms: Number of washroom attached with bedroom
# - Twashrooms: total number of washroom in the house.
# - Roof: Does the house has roof(yes or no)
# - Roof(Area): Total area of the terrace
# - Lawn(Area): Area of the lawn including garden and parking
# - Nfloor: Number of floors in the house
# - API: Air purity index api is in percentage for example if api is 85 it means its 85% of the standard api for the city.
# - ANB: Amenities near by amenities like hospital, park , multiplex , malls etc within 2 miles.
# - Expected price: price expected by seller.
# - Grade: Grade provided by company that depends on the condition and other features mentioned in the data. *(Note A is best garde and E is worst.)*
#
#  Evaluation: The metric of evaluation for this prediction problem is Accuracy.

# %%
old_training_df = pd.read_csv("TRAINING_.csv")
old_training_df.sample(5)
# Out:
#         id  Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms roof  \
# 4508  4509          355    8.0        2.0          2.0         4.0   no
# 3805  3806          335    7.0        8.0          6.0         8.0   no
# 1218  1219          313    5.0        4.0          2.0         4.0  yes
# 366    367          355    5.0        4.0          4.0         6.0   NO
# 6485  6486          320    9.0        7.0          5.0         7.0   NO
#
#       Roof(Area)  Lawn(Area)  Nfloors   API  ANB Grade EXPECTED
# 4508         0.0       107.0        1  93.0    5     C    4110$
# 3805         0.0        70.0        7  89.0    2     B    4466$
# 1218        86.0        82.0        2  82.0    5     D    3724$
# 366          0.0        97.0        4  74.0    1     D    3418$
# 6485         0.0        92.0        5  77.0    6     B    4092$

# %%
old_training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           7000 non-null   int64
#  1   Area(total)  7000 non-null   int64
#  2   Troom        6998 non-null   float64
#  3   Nbedrooms    6997 non-null   float64
#  4   Nbwashrooms  6998 non-null   float64
#  5   Twashrooms   6999 non-null   float64
#  6   roof         5647 non-null   object
#  7   Roof(Area)   5647 non-null   float64
#  8   Lawn(Area)   6998 non-null   float64
#  9   Nfloors      7000 non-null   int64
#  10  API          6999 non-null   float64
#  11  ANB          7000 non-null   int64
#  12  Grade        7000 non-null   object
#  13  EXPECTED     7000 non-null   object
# dtypes: float64(7), int64(4), object(3)
# memory usage: 765.8+ KB

# %% [markdown]
# * removing "$" sign from "EXPECTED" column

# %%
old_training_df["EXPECTED"] = old_training_df["EXPECTED"].str.replace("$","").astype("float")

# %%
training_df = old_training_df.drop(columns=(["roof", "Roof(Area)", "Grade", "id"]))

# %% [markdown]
# ## Handling Missing Data

# %%
training_df.isnull().sum()
# Out:
# Area(total)    0
# Troom          2
# Nbedrooms      3
# Nbwashrooms    2
# Twashrooms     1
# Lawn(Area)     2
# Nfloors        0
# API            1
# ANB            0
# EXPECTED       0
# dtype: int64

# %% [markdown]
# * fill missing values using mean,mode

# %%
#mode
mode_col = ["Troom","Nbedrooms","Nbwashrooms","Twashrooms"]

#mean
mean_col= ["Lawn(Area)", "API"]

# %%
from sklearn.impute import SimpleImputer


si = SimpleImputer(strategy = "most_frequent")

training_df[mode_col] = pd.DataFrame(si.fit_transform(training_df[mode_col]), index = training_df.index, columns = mode_col)


si = SimpleImputer(strategy = "mean")
training_df[mean_col] = pd.DataFrame(si.fit_transform(training_df[mean_col]), index = training_df.index, columns = mean_col)

# %%
training_df.isnull().sum()
# Out:
# Area(total)    0
# Troom          0
# Nbedrooms      0
# Nbwashrooms    0
# Twashrooms     0
# Lawn(Area)     0
# Nfloors        0
# API            0
# ANB            0
# EXPECTED       0
# dtype: int64

# %%
training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area(total)  7000 non-null   int64
#  1   Troom        7000 non-null   float64
#  2   Nbedrooms    7000 non-null   float64
#  3   Nbwashrooms  7000 non-null   float64
#  4   Twashrooms   7000 non-null   float64
#  5   Lawn(Area)   7000 non-null   float64
#  6   Nfloors      7000 non-null   int64
#  7   API          7000 non-null   float64
#  8   ANB          7000 non-null   int64
#  9   EXPECTED     7000 non-null   float64
# dtypes: float64(7), int64(3)
# memory usage: 547.0 KB

# %% [markdown]
# * ------- all missing values are handled in training_df ( 9 - columns )----------------

# %% [markdown]
# ## scaling

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

df_training_scale = pd.DataFrame(ss.fit_transform(training_df), columns=training_df.columns, index=training_df.index)

# %%
df_training_scale
# Out:
#       Area(total)     Troom  Nbedrooms  Nbwashrooms  Twashrooms  Lawn(Area)  \
# 0       -0.984255  0.695196  -1.810562    -1.881612   -1.657462   -1.181860
# 1        0.913637 -0.713102   1.214099     1.876064    1.655947   -0.589151
# 2       -1.519558  0.695196  -0.600698    -0.629053   -0.994780   -1.012515
# 3        0.135015 -1.417250  -0.600698    -1.255332   -0.994780    0.088230
# 4       -1.470894  1.399345   0.004235    -0.629053   -0.332098    0.596266
# ...           ...       ...        ...          ...         ...         ...
# 6995    -0.935591  0.695196  -1.810562    -1.881612   -1.657462   -1.012515
# 6996     0.767645 -1.417250  -1.205630    -1.255332   -0.994780   -1.520551
# 6997    -0.935591 -0.713102  -0.600698    -1.255332   -0.994780   -0.843169
# 6998     0.621653  0.695196   1.214099     1.249785    0.993265    0.426921
# 6999    -0.546280 -1.417250   0.609167    -0.002774    0.330584   -0.843169
#
#        Nfloors       API       ANB  EXPECTED
# 0    -1.370481 -1.348076  0.297170 -0.423898
# 1     1.360183  1.520941 -1.467196  0.849083
# 2    -1.916614  0.761495  0.297170  0.327403
# 3     0.267917  0.592730 -1.467196 -1.157071
# 4    -0.278216  1.183409 -0.290952  1.020291
# ...        ...       ...       ...       ...
# 6995 -1.916614 -0.504247  0.885291 -0.643447
# 6996 -0.278216 -0.251099  0.297170 -1.404819
# 6997 -0.278216  1.436558  0.297170 -0.417856
# 6998 -0.278216  0.423964 -1.467196  0.909510
# 6999 -0.278216  1.436558 -0.879074 -1.245696
#
# [7000 rows x 10 columns]

# %% [markdown]
# ## k-mean

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=42, n_init='auto')

kmeans.fit(df_training_scale)
# Out:
# KMeans(n_clusters=5, n_init='auto', random_state=42)

# %%
training_df["cluster"] = kmeans.labels_

# %%
training_df["Roof(Area)"] = old_training_df["Roof(Area)"]

# %%
training_df.groupby(["cluster"])["Roof(Area)"].mean()
# Out:
# cluster
# 0    44.518554
# 1    46.198919
# 2    44.628081
# 3    49.198255
# 4    51.573296
# Name: Roof(Area), dtype: float64

# %%
zero = training_df["cluster"]==0
training_df.loc[zero] = training_df.loc[zero].fillna(value= 44.518554)


one = training_df["cluster"]==1
training_df.loc[one] = training_df.loc[one].fillna(value= 46.198919)


two = training_df["cluster"]==2
training_df.loc[two] = training_df.loc[two].fillna(value= 44.628081)


three = training_df["cluster"]==3
training_df.loc[three] = training_df.loc[three].fillna(value= 49.198255)


four = training_df["cluster"]==4
training_df.loc[four] = training_df.loc[four].fillna(value= 51.573296)

# %%
training_df.isnull().sum()
# Out:
# Area(total)    0
# Troom          0
# Nbedrooms      0
# Nbwashrooms    0
# Twashrooms     0
# Lawn(Area)     0
# Nfloors        0
# API            0
# ANB            0
# EXPECTED       0
# cluster        0
# Roof(Area)     0
# dtype: int64

# %% [markdown]
# * ---------------------- all missing values are handled in training_df ( 12 - columns, drop= [ "id" , "roof" ] ) --------------------------------

# %% [markdown]
# ## training_df

# %%
training_df.drop(columns=["cluster"], inplace=True)

# %%
training_df = pd.concat([training_df,old_training_df["Grade"]],axis=1)

# %%
training_df["Grade"] = training_df["Grade"].replace({"A":4, "B":3, "C":2, "D":1, "E":0})

# %%
training_df
# Out:
#       Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms  Lawn(Area)  \
# 0             305    8.0        2.0          1.0         3.0        76.0
# 1             344    6.0        7.0          7.0         8.0        83.0
# 2             294    8.0        4.0          3.0         4.0        78.0
# 3             328    5.0        4.0          2.0         4.0        91.0
# 4             295    9.0        5.0          3.0         5.0        97.0
# ...           ...    ...        ...          ...         ...         ...
# 6995          306    8.0        2.0          1.0         3.0        78.0
# 6996          341    5.0        3.0          2.0         4.0        72.0
# 6997          306    6.0        4.0          2.0         4.0        80.0
# 6998          338    8.0        7.0          6.0         7.0        95.0
# 6999          314    5.0        6.0          4.0         6.0        80.0
#
#       Nfloors   API  ANB  EXPECTED  Roof(Area)  Grade
# 0           2  63.0    4    3826.0    0.000000      1
# 1           7  97.0    1    4458.0    0.000000      3
# 2           1  88.0    4    4199.0   97.000000      2
# 3           5  86.0    1    3462.0    0.000000      1
# 4           4  93.0    3    4543.0   49.198255      2
# ...       ...   ...  ...       ...         ...    ...
# 6995        1  73.0    5    3717.0   44.628081      1
# 6996        4  76.0    4    3339.0  100.000000      1
# 6997        4  96.0    4    3829.0   83.000000      1
# 6998        4  84.0    1    4488.0    0.000000      3
# 6999        4  96.0    2    3418.0  109.000000      2
#
# [7000 rows x 12 columns]

# %% [markdown]
# ## x,y

# %%
X = training_df.drop(columns=["Grade"])
y = training_df["Grade"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

print(X_train.shape)
print(X_test.shape)
# Out:
# (5250, 11)
# (1750, 11)

# %% [markdown]
# ## scale

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_train_scale = pd.DataFrame(ss.fit_transform(X_train), index=X_train.index, columns=X_train.columns)
X_test_scale = pd.DataFrame(ss.transform(X_test), index=X_test.index, columns=X_test.columns)

# %% [markdown]
# ## <center>~ Applying Models ~

# %% [markdown]
# ## Applying ANN model
# * ann is gives good accuracy compaired to other model like - [ LogisticRegression, DecisionTreeClassifier, RandomForestClassifier,  GradientBoostingClassifier, XGBClassifier]

# %%
def set_seed(seed: int = 42) -> None:
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  tf.experimental.numpy.random.seed(seed)
  tf.random.set_seed(seed)
  os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
  os.environ['TF_DETERMINISTIC_OPS'] = '1'
  # Set a fixed value for the hash seed
  os.environ["PYTHONHASHSEED"] = str(seed)
  print(f"Random seed set as {seed}")

# %%
def plot_curve(history):
    history_df = pd.DataFrame(history.history)

    fig, ax = plt.subplots(1,2, figsize = (10,4))

    sns.lineplot(data = history_df,x = history_df.index+1, y = "loss", label = "training_loss", ax = ax[0])
    sns.lineplot(data = history_df,x = history_df.index+1, y = "val_loss", label = "validation_loss",ax = ax[0])


    sns.lineplot(data = history_df,x = history_df.index+1, y = "accuracy", label = "training_accuracy", ax = ax[1])
    sns.lineplot(data = history_df,x = history_df.index+1, y = "val_accuracy", label = "validation_accuracy", ax = ax[1])

    fig.suptitle("loss & accuracy curve plot")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## ann - 4 *

# %%
import tensorflow as tf
from tensorflow.keras.layers import InputLayer, Dense,Dropout

set_seed(42)

# model creation
ann4 = tf.keras.Sequential([
    InputLayer(input_shape=(11,)),

    Dense(150, 'relu'),
    Dropout(0.2),

    Dense(100, 'relu'),
    Dense(50, 'relu'),
    Dropout(0.2),

    Dense(5, 'softmax')])

# model compile
ann4.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# model fit
result4 = ann4.fit(X_train_scale, y_train, epochs=40, batch_size=12, validation_data=(X_test_scale, y_test))
# Out:
# Random seed set as 42
# Epoch 1/40
#  40/438 [=>............................] - ETA: 1s - loss: 1.5311 - accuracy: 0.3750
# 438/438 [==============================] - 3s 4ms/step - loss: 0.9613 - accuracy: 0.6707 - val_loss: 0.5592 - val_accuracy: 0.8034
# Epoch 2/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5313 - accuracy: 0.7981 - val_loss: 0.4092 - val_accuracy: 0.8514
# Epoch 3/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.4395 - accuracy: 0.8265 - val_loss: 0.3467 - val_accuracy: 0.8686
# Epoch 4/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.3864 - accuracy: 0.8514 - val_loss: 0.3090 - val_accuracy: 0.8846
# Epoch 5/40
# 438/438 [==============================] - 2s 3ms/step - loss: 0.3483 - accuracy: 0.8682 - val_loss: 0.3007 - val_accuracy: 0.8886
# Epoch 6/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.3100 - accuracy: 0.8808 - val_loss: 0.2600 - val_accuracy: 0.8994
# Epoch 7/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.2947 - accuracy: 0.8853 - val_loss: 0.2507 - val_accuracy: 0.9046
# Epoch 8/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.2658 - accuracy: 0.8987 - val_loss: 0.2381 - val_accuracy: 0.8943
# Epoch 9/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.2713 - accuracy: 0.8928 - val_loss: 0.2343 - val_accuracy: 0.9029
# Epoch 10/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.2599 - accuracy: 0.9004 - val_loss: 0.2397 - val_accuracy: 0.9046
# Epoch 11/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.2511 - accuracy: 0.9082 - val_loss: 0.2144 - val_accuracy: 0.9137
# Epoch 12/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.2379 - accuracy: 0.9034 - val_loss: 0.2105 - val_accuracy: 0.9120
# Epoch 13/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.2338 - accuracy: 0.9057 - val_loss: 0.2055 - val_accuracy: 0.9103
# Epoch 14/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.2293 - accuracy: 0.9055 - val_loss: 0.2095 - val_accuracy: 0.9069
# Epoch 15/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.2133 - accuracy: 0.9156 - val_loss: 0.2168 - val_accuracy: 0.9080
# Epoch 16/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.2184 - accuracy: 0.9166 - val_loss: 0.1899 - val_accuracy: 0.9217
# Epoch 17/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.2075 - accuracy: 0.9141 - val_loss: 0.1994 - val_accuracy: 0.9154
# Epoch 18/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.2119 - accuracy: 0.9175 - val_loss: 0.1848 - val_accuracy: 0.9229
# Epoch 19/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.2077 - accuracy: 0.9179 - val_loss: 0.1918 - val_accuracy: 0.9166
# Epoch 20/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1983 - accuracy: 0.9194 - val_loss: 0.1923 - val_accuracy: 0.9183
# Epoch 21/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1981 - accuracy: 0.9208 - val_loss: 0.1834 - val_accuracy: 0.9263
# Epoch 22/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1965 - accuracy: 0.9211 - val_loss: 0.2133 - val_accuracy: 0.9086
# Epoch 23/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1845 - accuracy: 0.9263 - val_loss: 0.1882 - val_accuracy: 0.9234
# Epoch 24/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1875 - accuracy: 0.9232 - val_loss: 0.2011 - val_accuracy: 0.9097
# Epoch 25/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1779 - accuracy: 0.9263 - val_loss: 0.1743 - val_accuracy: 0.9263
# Epoch 26/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1816 - accuracy: 0.9269 - val_loss: 0.1663 - val_accuracy: 0.9291
# Epoch 27/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1811 - accuracy: 0.9276 - val_loss: 0.1700 - val_accuracy: 0.9263
# Epoch 28/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1693 - accuracy: 0.9301 - val_loss: 0.1620 - val_accuracy: 0.9337
# Epoch 29/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1728 - accuracy: 0.9291 - val_loss: 0.1733 - val_accuracy: 0.9280
# Epoch 30/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1718 - accuracy: 0.9259 - val_loss: 0.1745 - val_accuracy: 0.9240
# Epoch 31/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1728 - accuracy: 0.9291 - val_loss: 0.1698 - val_accuracy: 0.9251
# Epoch 32/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1742 - accuracy: 0.9299 - val_loss: 0.1709 - val_accuracy: 0.9229
# Epoch 33/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1693 - accuracy: 0.9310 - val_loss: 0.1579 - val_accuracy: 0.9314
# Epoch 34/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1676 - accuracy: 0.9288 - val_loss: 0.1767 - val_accuracy: 0.9223
# Epoch 35/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1663 - accuracy: 0.9328 - val_loss: 0.1610 - val_accuracy: 0.9269
# Epoch 36/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1599 - accuracy: 0.9339 - val_loss: 0.1629 - val_accuracy: 0.9326
# Epoch 37/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1590 - accuracy: 0.9354 - val_loss: 0.1500 - val_accuracy: 0.9331
# Epoch 38/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1588 - accuracy: 0.9322 - val_loss: 0.1510 - val_accuracy: 0.9343
# Epoch 39/40
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1538 - accuracy: 0.9383 - val_loss: 0.1651 - val_accuracy: 0.9291
# Epoch 40/40
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1651 - accuracy: 0.9330 - val_loss: 0.1704 - val_accuracy: 0.9251

# %%
plot_curve(result4)

# %% [markdown]
# * model

# %%
ann4.evaluate(X_test_scale, y_test)
# Out:
# 55/55 [==============================] - 0s 2ms/step - loss: 0.1704 - accuracy: 0.9251
# [0.17041394114494324, 0.9251428842544556]

# %%
y_pred_ann_4 = ann4.predict(X_test_scale)
# Out:
# 55/55 [==============================] - 0s 1ms/step

# %%
y_pred_4 = np.argmax(y_pred_ann_4, axis= 1)

# %%
print(classification_report(y_test, y_pred_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.95      0.94      0.94       514
#            2       0.93      0.95      0.94       747
#            3       0.94      0.86      0.90       371
#            4       0.79      0.99      0.88       112
#
#     accuracy                           0.93      1750
#    macro avg       0.72      0.75      0.73      1750
# weighted avg       0.92      0.93      0.92      1750
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
ann4.save("ann_model_4")
# Out:
# INFO:tensorflow:Assets written to: ann_model_4\assets
# INFO:tensorflow:Assets written to: ann_model_4\assets

# %%
load_model_4 = tf.keras.models.load_model("ann_model_4")

# %%
pd.Series(np.argmax(load_model_4.predict(X_test_scale),axis=1)).value_counts()
# Out:
# 55/55 [==============================] - 0s 1ms/step
# 2    762
# 1    507
# 3    341
# 4    140
# Name: count, dtype: int64

# %%
# ann5.evaluate(X_test_scale, y_test)
# y_pred_ann5 = ann5.predict(X_test_scale)
# y_pred_5 = np.argmax(y_pred_ann5, axis= 1)
# print(classification_report(y_test, y_pred_5))

# # -----------------------------------------
# ann6.save("ann_model6")
# load_model_6 = tf.keras.models.load_model("ann_model6")
# pd.Series(np.argmax(load_model_6.predict(X_test_scale),axis=1)).value_counts()

# %% [markdown]
# ## ann - 5

# %%
import tensorflow as tf
from tensorflow.keras.layers import InputLayer, Dense,Dropout

set_seed(42)

# model creation
ann5 = tf.keras.Sequential([
    InputLayer(input_shape=(11,)),
    Dense(400, 'relu'),
    Dropout(0.3),
    Dense(340, 'relu'),
    Dropout(0.2),
    Dense(270, 'relu'),
    Dropout(0.3),
    Dense(130, 'relu'),
    Dropout(0.2),
    Dense(70, 'relu'),
    Dropout(0.3),
    Dense(5, 'softmax')])
# model compile
ann5.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# model fit
result5 = ann5.fit(X_train_scale, y_train, epochs=50, batch_size=12, validation_data=(X_test_scale, y_test))
# Out:
# Random seed set as 42
# Epoch 1/50
# 438/438 [==============================] - 3s 4ms/step - loss: 1.0345 - accuracy: 0.5857 - val_loss: 0.5729 - val_accuracy: 0.8046
# Epoch 2/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.6066 - accuracy: 0.7703 - val_loss: 0.4057 - val_accuracy: 0.8434
# Epoch 3/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.4864 - accuracy: 0.8141 - val_loss: 0.3380 - val_accuracy: 0.8754
# Epoch 4/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.4169 - accuracy: 0.8366 - val_loss: 0.3235 - val_accuracy: 0.8623
# Epoch 5/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3604 - accuracy: 0.8568 - val_loss: 0.2872 - val_accuracy: 0.8943
# Epoch 6/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3478 - accuracy: 0.8646 - val_loss: 0.2535 - val_accuracy: 0.9091
# Epoch 7/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3280 - accuracy: 0.8672 - val_loss: 0.2468 - val_accuracy: 0.9114
# Epoch 8/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3016 - accuracy: 0.8853 - val_loss: 0.2480 - val_accuracy: 0.8994
# Epoch 9/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.3016 - accuracy: 0.8800 - val_loss: 0.2229 - val_accuracy: 0.9069
# Epoch 10/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2857 - accuracy: 0.8865 - val_loss: 0.2473 - val_accuracy: 0.8971
# Epoch 11/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2705 - accuracy: 0.8964 - val_loss: 0.2163 - val_accuracy: 0.9080
# Epoch 12/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2602 - accuracy: 0.8941 - val_loss: 0.2118 - val_accuracy: 0.9109
# Epoch 13/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2604 - accuracy: 0.8979 - val_loss: 0.2158 - val_accuracy: 0.9126
# Epoch 14/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2584 - accuracy: 0.8958 - val_loss: 0.1963 - val_accuracy: 0.9234
# Epoch 15/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2514 - accuracy: 0.9006 - val_loss: 0.2063 - val_accuracy: 0.9183
# Epoch 16/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2350 - accuracy: 0.9076 - val_loss: 0.1993 - val_accuracy: 0.9160
# Epoch 17/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2318 - accuracy: 0.9067 - val_loss: 0.1933 - val_accuracy: 0.9166
# Epoch 18/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2230 - accuracy: 0.9158 - val_loss: 0.1824 - val_accuracy: 0.9166
# Epoch 19/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2177 - accuracy: 0.9141 - val_loss: 0.2080 - val_accuracy: 0.9034
# Epoch 20/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2183 - accuracy: 0.9139 - val_loss: 0.1679 - val_accuracy: 0.9320
# Epoch 21/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2126 - accuracy: 0.9164 - val_loss: 0.1927 - val_accuracy: 0.9217
# Epoch 22/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2103 - accuracy: 0.9095 - val_loss: 0.1830 - val_accuracy: 0.9211
# Epoch 23/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2008 - accuracy: 0.9248 - val_loss: 0.1736 - val_accuracy: 0.9309
# Epoch 24/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.2025 - accuracy: 0.9179 - val_loss: 0.1792 - val_accuracy: 0.9291
# Epoch 25/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1930 - accuracy: 0.9219 - val_loss: 0.1745 - val_accuracy: 0.9234
# Epoch 26/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1931 - accuracy: 0.9227 - val_loss: 0.1807 - val_accuracy: 0.9229
# Epoch 27/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1925 - accuracy: 0.9248 - val_loss: 0.1660 - val_accuracy: 0.9331
# Epoch 28/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1781 - accuracy: 0.9293 - val_loss: 0.1688 - val_accuracy: 0.9251
# Epoch 29/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1918 - accuracy: 0.9238 - val_loss: 0.1785 - val_accuracy: 0.9223
# Epoch 30/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1873 - accuracy: 0.9238 - val_loss: 0.1748 - val_accuracy: 0.9240
# Epoch 31/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1789 - accuracy: 0.9290 - val_loss: 0.1817 - val_accuracy: 0.9200
# Epoch 32/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1826 - accuracy: 0.9215 - val_loss: 0.1569 - val_accuracy: 0.9331
# Epoch 33/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1751 - accuracy: 0.9307 - val_loss: 0.1543 - val_accuracy: 0.9383
# Epoch 34/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1786 - accuracy: 0.9291 - val_loss: 0.1877 - val_accuracy: 0.9240
# Epoch 35/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1684 - accuracy: 0.9290 - val_loss: 0.1614 - val_accuracy: 0.9240
# Epoch 36/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1707 - accuracy: 0.9312 - val_loss: 0.1694 - val_accuracy: 0.9303
# Epoch 37/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1652 - accuracy: 0.9356 - val_loss: 0.1649 - val_accuracy: 0.9263
# Epoch 38/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1625 - accuracy: 0.9349 - val_loss: 0.1616 - val_accuracy: 0.9297
# Epoch 39/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1620 - accuracy: 0.9339 - val_loss: 0.1788 - val_accuracy: 0.9257
# Epoch 40/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1681 - accuracy: 0.9366 - val_loss: 0.1706 - val_accuracy: 0.9280
# Epoch 41/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1600 - accuracy: 0.9362 - val_loss: 0.1585 - val_accuracy: 0.9349
# Epoch 42/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1596 - accuracy: 0.9398 - val_loss: 0.1623 - val_accuracy: 0.9326
# Epoch 43/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1577 - accuracy: 0.9314 - val_loss: 0.1840 - val_accuracy: 0.9126
# Epoch 44/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1611 - accuracy: 0.9396 - val_loss: 0.1449 - val_accuracy: 0.9366
# Epoch 45/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1534 - accuracy: 0.9400 - val_loss: 0.1596 - val_accuracy: 0.9349
# Epoch 46/50
# 438/438 [==============================] - 2s 5ms/step - loss: 0.1540 - accuracy: 0.9389 - val_loss: 0.1734 - val_accuracy: 0.9263
# Epoch 47/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1504 - accuracy: 0.9446 - val_loss: 0.1655 - val_accuracy: 0.9269
# Epoch 48/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1394 - accuracy: 0.9432 - val_loss: 0.1644 - val_accuracy: 0.9320
# Epoch 49/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1448 - accuracy: 0.9438 - val_loss: 0.1568 - val_accuracy: 0.9320
# Epoch 50/50
# 438/438 [==============================] - 2s 4ms/step - loss: 0.1417 - accuracy: 0.9457 - val_loss: 0.1502 - val_accuracy: 0.9360

# %%
plot_curve(result5)

# %%
ann5.evaluate(X_test_scale, y_test)
# Out:
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1792 - accuracy: 0.9217
# [0.17924000322818756, 0.9217143058776855]

# %%
y_pred_ann5 = ann5.predict(X_test_scale)
# Out:
# 55/55 [==============================] - 0s 2ms/step

# %%
y_pred_5 = np.argmax(y_pred_ann5, axis= 1)

# %%
print(classification_report(y_test, y_pred_5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.95      0.94      0.95       514
#            2       0.91      0.97      0.94       747
#            3       0.90      0.88      0.89       371
#            4       0.99      0.73      0.84       112
#
#     accuracy                           0.92      1750
#    macro avg       0.75      0.70      0.72      1750
# weighted avg       0.92      0.92      0.92      1750
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Manish Gupta\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# * save model (ann5)

# %%
ann5.save("ann_model5")
# Out:
# INFO:tensorflow:Assets written to: ann_model5\assets
# INFO:tensorflow:Assets written to: ann_model5\assets

# %%
load_model_5 = tf.keras.models.load_model("ann_model5")

# %%
pd.Series(np.argmax(load_model_5.predict(X_test_scale),axis=1)).value_counts()
# Out:
# 55/55 [==============================] - 0s 2ms/step
# 2    795
# 1    509
# 3    363
# 4     83
# Name: count, dtype: int64

# %%
# !zip -r /content/ann_model5.zip /content/ann_model5
# Out:
# 'zip' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## ann -6 v.

# %%
import tensorflow as tf
from tensorflow.keras.layers import InputLayer, Dense,Dropout

set_seed(42)

# model creation
ann6 = tf.keras.Sequential([
    InputLayer(input_shape=(11,)),

    Dense(256, 'relu'),
    Dropout(0.2),

    Dense(128, 'relu'),
    Dense(64, 'relu'),
    Dense(32, 'relu'),

    Dropout(0.2),

    Dense(5, 'softmax')])

# model compile
ann6.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# model fit
result6 = ann6.fit(X_train_scale, y_train, epochs=50,batch_size=12, validation_data=(X_test_scale, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Manish Gupta\Desktop\skillenza\ann-- cleaned  - % accuracy -\train_test_submission copy.ipynb Cell 66 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/ann--%20cleaned%20%20-%20%25%20accuracy%20-/train_test_submission%20copy.ipynb#Y122sZmlsZQ%3D%3D?line=0'>1</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/ann--%20cleaned%20%20-%20%25%20accuracy%20-/train_test_submission%20copy.ipynb#Y122sZmlsZQ%3D%3D?line=1'>2</a> from tensorflow.keras.layers import InputLayer, Dense,Dropout
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/ann--%20cleaned%20%20-%20%25%20accuracy%20-/train_test_submission%20copy.ipynb#Y122sZmlsZQ%3D%3D?line=3'>4</a> set_seed(42)
#       <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/ann--%20cleaned%20%20-%20%25%20accuracy%20-/train_test_submission%20copy.ipynb#Y122sZmlsZQ%3D%3D?line=5'>6</a> # model creation
#       <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/ann--%20cleaned%20%20-%20%25%20accuracy%20-/train_test_submission%20copy.ipynb#Y122sZmlsZQ%3D%3D?line=6'>7</a> ann6 = tf.keras.Sequential([
#       <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/ann--%20cleaned%20%20-%20%25%20accuracy%20-/train_test_submission%20copy.ipynb#Y122sZmlsZQ%3D%3D?line=7'>8</a>     InputLayer(input_shape=(11,)),
#       <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/ann--%20cleaned%20%20-%20%25%20accuracy%20-/train_test_submission%20copy.ipynb#Y122sZmlsZQ%3D%3D?line=8'>9</a>
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/ann--%20cleaned%20%20-%20%25%20accuracy%20-/train_test_submission%20copy.ipynb#Y122sZmlsZQ%3D%3D?line=17'>18</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/Manish%20Gupta/Desktop/skillenza/ann--%20cleaned%20%20-%20%25%20accuracy%20-/train_test_submission%20copy.ipynb#Y122sZmlsZQ%3D%3D?line=18'>19</a>     Dense(5, 'softmax')])
#
# NameError: name 'set_seed' is not defined

# %%
plot_curve(result6)

# %%
.py.py.py.

# %%
ann6.save("ann_model6")

# %%
load_model_6 = tf.keras.models.load_model("ann_model6")

# %%
pd.Series(np.argmax(load_model_6.predict(X_test_scale),axis=1)).value_counts()
# Out:
# 44/44 [==============================] - 0s 2ms/step
# 2    601
# 1    417
# 3    302
# 4     79
# 0      1
# dtype: int64

# %%
# !zip -r /content/ann_model_6.zip /content/ann_model6
# Out:
#   adding: content/ann_model6/ (stored 0%)
#   adding: content/ann_model6/keras_metadata.pb (deflated 90%)
#   adding: content/ann_model6/fingerprint.pb (stored 0%)
#   adding: content/ann_model6/variables/ (stored 0%)
#   adding: content/ann_model6/variables/variables.index (deflated 59%)
#   adding: content/ann_model6/variables/variables.data-00000-of-00001 (deflated 16%)
#   adding: content/ann_model6/assets/ (stored 0%)
#   adding: content/ann_model6/saved_model.pb (deflated 88%)

# %% [markdown]
# # <center> Working on test data

# %%
test_df = pd.read_csv('TEST_.csv')
test_df.sample(5)
# Out:
#         id  Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms roof  \
# 2129  2130          326    8.0        5.0          6.0           7  YES
# 1278  1279          331    6.0        6.0          4.0           6  YES
# 3153  3154          328    5.0        8.0          6.0           8   no
# 2417  2418          296    9.0        7.0          5.0           7   no
# 2179  2180          348    7.0        7.0          4.0           6   no
#
#       Roof(Area)  Lawn(Area)  Nfloors   API  ANB EXPECTED
# 2129        91.0       103.0        7  93.0    5    4812$
# 1278       110.0        90.0        4  65.0    4    3709$
# 3153         0.0       105.0        5  84.0    2    4346$
# 2417         0.0       105.0        7  97.0    6    4709$
# 2179         0.0        97.0        5  77.0    3    4250$

# %%
test_df.shape
# Out:
# (3299, 13)

# %%
test_df.isnull().sum()[test_df.isnull().sum()>0]
# Out:
# Troom            1
# Nbedrooms        1
# Nbwashrooms      1
# roof           653
# Roof(Area)     653
# Lawn(Area)       1
# API              1
# dtype: int64

# %%
test_df['EXPECTED'] = test_df['EXPECTED'].str.strip('$').astype(float)

# %%
test_df.drop(columns=['id'], inplace=True)

# %%
new_test_df = test_df.drop(columns = ['roof', 'Roof(Area)'])
new_test_df.head(7)
# Out:
#    Area(total)  Troom  Nbedrooms  Nbwashrooms  Twashrooms  Lawn(Area)  \
# 0          348    9.0        5.0          3.0           5        84.0
# 1          311    6.0        5.0          5.0           6        86.0
# 2          342    5.0        6.0          6.0           7        85.0
# 3          329    7.0        7.0          4.0           6       105.0
# 4          307    6.0        2.0          3.0           4        76.0
# 5          297    6.0        6.0          4.0           6       103.0
# 6          292    9.0        7.0          6.0           7       101.0
#
#    Nfloors   API  ANB  EXPECTED
# 0        5  91.0    6    4422.0
# 1        6  83.0    4    3432.0
# 2        4  95.0    5    4066.0
# 3        5  97.0    6    4322.0
# 4        2  64.0    4    3031.0
# 5        6  73.0    6    4223.0
# 6        5  88.0    5    4993.0

# %%
new_test_df.isnull().sum()[new_test_df.isnull().sum() > 0]
# Out:
# Troom          1
# Nbedrooms      1
# Nbwashrooms    1
# Lawn(Area)     1
# API            1
# dtype: int64

# %%
mode_cols = ['Troom', 'Nbedrooms', 'Nbwashrooms']
mean_cols = ['Lawn(Area)', 'API']

new_test_df[mode_cols] = new_test_df[mode_cols].fillna(test_df[mode_cols].mode().iloc[0])
new_test_df[mean_cols] = new_test_df[mean_cols].fillna(test_df[mean_cols].mean())

# %%
scaler = StandardScaler()
new_test_df_scale = pd.DataFrame(scaler.fit_transform(new_test_df), index = new_test_df.index, columns=new_test_df.columns)
new_test_df_scale.head(2)
# Out:
#    Area(total)     Troom  Nbedrooms  Nbwashrooms  Twashrooms  Lawn(Area)  \
# 0     1.154616  1.421814  -0.000933    -0.650541   -0.341896   -0.517482
# 1    -0.665650 -0.691688  -0.000933     0.642311    0.339623   -0.348648
#
#     Nfloors       API       ANB  EXPECTED
# 0  0.276844  1.004131  1.477486  0.815526
# 1  0.838533  0.326682  0.298570 -1.222186

# %%
km = KMeans(n_clusters= 5, random_state=42, n_init = 10)
km.fit(new_test_df_scale)
# Out:
# KMeans(n_clusters=5, n_init=10, random_state=42)

# %%
new_test_df['K_cluster'] = km.labels_

# %%
new_test_df['Roof(Area)'] = test_df['Roof(Area)']

# %%
new_test_df.groupby(by='K_cluster')['Roof(Area)'].mean()
# Out:
# K_cluster
# 0    49.977186
# 1    46.112903
# 2    46.326718
# 3    46.603912
# 4    47.479920
# Name: Roof(Area), dtype: float64

# %%
cluster_median_mapping = {
    0: 49.977186,
    1: 46.112903,
    2: 46.326718,
    3: 46.603912,
    4: 47.479920
}

# Fill missing values with the cluster mean
new_test_df['Roof(Area)'].fillna(new_test_df['K_cluster'].map(cluster_median_mapping), inplace=True)

# %%
new_test_df.drop(columns=['K_cluster'], inplace=True)

# %%
## Standardizing
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
test_std = pd.DataFrame(scale.fit_transform(new_test_df), index=new_test_df.index, columns=new_test_df.columns)

# %%
test_std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3299 entries, 0 to 3298
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area(total)  3299 non-null   float64
#  1   Troom        3299 non-null   float64
#  2   Nbedrooms    3299 non-null   float64
#  3   Nbwashrooms  3299 non-null   float64
#  4   Twashrooms   3299 non-null   float64
#  5   Lawn(Area)   3299 non-null   float64
#  6   Nfloors      3299 non-null   float64
#  7   API          3299 non-null   float64
#  8   ANB          3299 non-null   float64
#  9   EXPECTED     3299 non-null   float64
#  10  Roof(Area)   3299 non-null   float64
# dtypes: float64(11)
# memory usage: 283.6 KB

# %% [markdown]
# ## load model

# %%
load_model = tf.keras.models.load_model('ann_model_4')

# %%
pd.Series(np.argmax(load_model.predict(test_std), axis=1)).value_counts()
# Out:
# 104/104 [==============================] - 0s 3ms/step
# 2    1432
# 1     983
# 3     625
# 4     257
# 0       2
# Name: count, dtype: int64

# %%
final_df = pd.DataFrame()

# %% [markdown]
# # read test_.csv

# %%
test_df = pd.read_csv('TEST_.csv')

# %%
final_df['id'] = test_df['id']

# %%
final_df["Grade"] = np.argmax(load_model.predict(test_std), axis=1)
# Out:
# 104/104 [==============================] - 0s 2ms/step

# %%
final_df["Grade"].replace({4:"A", 3:"B", 2:"C", 1:"D", 0:"E"}, inplace=True)

# %%
final_df.to_csv('submission_4.csv', index=False)

# %% [markdown]
# ## save model

# %%
# ann5.evaluate(X_test_scale, y_test)
# y_pred_ann5 = ann5.predict(X_test_scale)
# y_pred_5 = np.argmax(y_pred_ann5, axis= 1)
# print(classification_report(y_test, y_pred_5))

# # -----------------------------------------
# ann6.save("ann_model6")
# load_model_6 = tf.keras.models.load_model("ann_model6")
# pd.Series(np.argmax(load_model_6.predict(X_test_scale),axis=1)).value_counts()
# # ------------------------------------------

# !zip -r /content/ann_model_6.zip /content/ann_model6
